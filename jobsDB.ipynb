# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarLoOscar/python_Data_Science/blob/main/jobsDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4 as bs
import urllib.request
import json

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

articles = []

for page in range(1,7):
    url = f'https://hk.jobsdb.com/java-jobs?page={page}&salaryrange=0-30000&salarytype=monthly&sortmode=ListedDate'
    req = urllib.request.Request(url, headers=headers)

    source = urllib.request.urlopen(req).read()

    soup = bs.BeautifulSoup(source, 'lxml')

    divs = soup.find_all('div', {'data-search-sol-meta': True})

    for div in divs:
        job_link = div.find('a', {'data-automation': 'job-list-view-job-link'})
        job_title = div.find('a', {'data-automation': 'jobTitle'})
        job_company = div.find('a', {'data-automation': 'jobCompany'})
        job_location = div.find('a', {'data-automation': 'jobLocation'})
        job_listing_date = div.find('span', {'data-automation': 'jobListingDate'})

        if job_link and job_title and job_company and job_location and job_listing_date:
        # print(f"Job Link: https://hk.jobsdb.com{job_link.get('href')}")
        # print(f"Job Title: {job_title.text.strip()}")
        # print(f"Job Company: {job_company.text.strip()}")
        # print(f"Job Location: {job_location.text.strip()}")
        # print('-' * 80)
          articles.append({
            'job_Link': f"https://hk.jobsdb.com{job_link.get('href')}",
            'job_title': job_title.text.strip(),
            'job_company': job_company.text.strip(),
            'job_location': job_location.text.strip(),
           'job_listing_date': job_listing_date.text.strip()
        })

articles_json = json.dumps(articles, ensure_ascii=False, indent=4)
print(articles_json)
# Out:
# [
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74794841?type=standard&ref=search-standalone",
#         "job_title": "System Analyst – Java (Ref:JD-SA)",
#         "job_company": "Public Bank (Hong Kong) Ltd",
#         "job_location": "Hong Kong",
#         "job_listing_date": "1m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75959785?type=standout&ref=search-standalone",
#         "job_title": "Senior Frontend Developer",
#         "job_company": "Maven Thoughts Limited",
#         "job_location": "Kwun Tong District",
#         "job_listing_date": "2m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75959605?type=standard&ref=search-standalone",
#         "job_title": "Programmer (Full-time) Information Systems & Technology Department",
#         "job_company": "Hong Kong Adventist Hospital - Stubbs Road",
#         "job_location": "Tsuen Wan District",
#         "job_listing_date": "9m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75959570?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer / System Analyst",
#         "job_company": "Gorilla Group Limited",
#         "job_location": "Tsuen Wan District",
#         "job_listing_date": "10m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75959454?type=standout&ref=search-standalone",
#         "job_title": "Software Developer",
#         "job_company": "Sportshouse Limited",
#         "job_location": "Tsuen Wan District",
#         "job_listing_date": "15m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75959167?type=standout&ref=search-standalone",
#         "job_title": "Mobile Developer",
#         "job_company": "Shanghai Commercial Bank Ltd",
#         "job_location": "Kwai Hing",
#         "job_listing_date": "25m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74668135?type=standout&ref=search-standalone",
#         "job_title": "System Analyst / Senior System Analyst (IT System Development)",
#         "job_company": "Shanghai Commercial Bank Ltd",
#         "job_location": "Kwai Hing",
#         "job_listing_date": "26m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75248257?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer (at the rank of IT Officer)",
#         "job_company": "Hong Kong Shue Yan University",
#         "job_location": "North Point",
#         "job_listing_date": "27m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75959008?type=standout&ref=search-standalone",
#         "job_title": "Project Officer/ Assistant Project Officer",
#         "job_company": "Hong Kong Quality Assurance Agency",
#         "job_location": "North Point",
#         "job_listing_date": "30m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74521875?type=standout&ref=search-standalone",
#         "job_title": "Senior Consultant / Consultant, Data Engineer, Technology Enablement (MJ003358)",
#         "job_company": "KPMG",
#         "job_location": "Wong Chuk Hang",
#         "job_listing_date": "31m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75958885?type=standout&ref=search-standalone",
#         "job_title": "Senior / Application Development Manager (Card and Payment Solution)",
#         "job_company": "Bank of China (Hong Kong) Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "34m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75223134?type=standout&ref=search-standalone",
#         "job_title": "Customer Support Executive/Product Developer (Garment Trims / Packaging)",
#         "job_company": "Able Choice Personnel Consultancy",
#         "job_location": "Lai Chi Kok",
#         "job_listing_date": "36m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75958559?type=standard&ref=search-standalone",
#         "job_title": "SEO and Website Developer",
#         "job_company": "Diestel & Partners (Dental Surgeons) Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "46m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75958333?type=standout&ref=search-standalone",
#         "job_title": "Senior / Application Development Manager (Data Platform Management)",
#         "job_company": "Bank of China (Hong Kong) Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "53m ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75957908?type=standout&ref=search-standalone",
#         "job_title": "Full Stack Developer (eCommerce focus)",
#         "job_company": "Talent Axis Management Consulting Group Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74860503?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer (Fresh graduates are welcome)",
#         "job_company": "ParaDM Company Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74860574?type=standout&ref=search-standalone",
#         "job_title": "System Analyst",
#         "job_company": "ParaDM Company Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/73330943?type=standout&ref=search-standalone",
#         "job_title": "Implementation Engineer",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74411768?type=standout&ref=search-standalone",
#         "job_title": "Technical Support Engineer",
#         "job_company": "Q P Group Holdings Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74489370?type=standard&ref=search-standalone",
#         "job_title": "System Analyst (Web) - Multiple vacancies",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74489417?type=standard&ref=search-standalone",
#         "job_title": "PHP Developer / Senior PHP Developer - Multiple vacancies (Fresh Graduate...",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74489566?type=standard&ref=search-standalone",
#         "job_title": "Full Stack Web Developer (PHP and React) / Mobile App Developer (PHP and...",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74486027?type=standard&ref=search-standalone",
#         "job_title": "Programmers / Analyst Programmer (Java) - Fresh Graduate Welcome",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74485959?type=standard&ref=search-standalone",
#         "job_title": "Application Support Engineer",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74485802?type=standard&ref=search-standalone",
#         "job_title": "Application Support Specialist",
#         "job_company": "Shiji Information Technology (Hong Kong) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75957030?type=standout&ref=search-standalone",
#         "job_title": "Data Scientist - Conglomerate",
#         "job_company": "Robert Walters (HK) Ltd",
#         "job_location": "Central and Western District",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75956506?type=standard&ref=search-standalone",
#         "job_title": "Engineer",
#         "job_company": "SYNCO (H.K.) Ltd",
#         "job_location": "Tai Po District",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75955819?type=standout&ref=search-standalone",
#         "job_title": "Mobile Developer (Android, Fully remote)",
#         "job_company": "Michael Page International (HK) Ltd",
#         "job_location": "Central and Western District",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75955026?type=standard&ref=search-standalone",
#         "job_title": "Software Engineer",
#         "job_company": "RTX Hong Kong Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75954936?type=standout&ref=search-standalone",
#         "job_title": "Data Engineer/Senior Data Engineer",
#         "job_company": "EY Mtel Solutions Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75954856?type=standout&ref=search-standalone",
#         "job_title": "Technology Consulting – Mtel – Software Engineer (Java / Node.js, Backend)",
#         "job_company": "EY Mtel Solutions Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75954690?type=standout&ref=search-standalone",
#         "job_title": "Software Quality Assurance - Senior/Associate",
#         "job_company": "EY Mtel Solutions Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75952199?type=standout&ref=search-standalone",
#         "job_title": "Post-doctoral Fellow (Job ID: 9895)",
#         "job_company": "The Hong Kong University of Science and Technology",
#         "job_location": "Clear Water Bay",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75951533?type=standout&ref=search-standalone",
#         "job_title": "5G/6G Solution Verification - Lead Engineer / Senior Engineer / Engineer",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75951484?type=standout&ref=search-standalone",
#         "job_title": "5G/6G Embedded System Design - Principal Engineer / Lead Engineer / Senior...",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75951296?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer",
#         "job_company": "Stelux Holdings Limited",
#         "job_location": "Wong Tai Sin District",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74650456?type=standout&ref=search-standalone",
#         "job_title": "ANALYST PROGRAMMER / SENIOR PROGRAMMER / PROGRAMMER",
#         "job_company": "Henderson Land Development Company Limited",
#         "job_location": "Central",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75951130?type=standout&ref=search-standalone",
#         "job_title": "Embedded Software Engineer",
#         "job_company": "Allystar Technoloy Co. Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75950806?type=standout&ref=search-standalone",
#         "job_title": "*Urgent*  IT Systems Specialist (Senior)",
#         "job_company": "Optimum Solutions (Singapore) Pte Ltd",
#         "job_location": "Central",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75555196?type=standout&ref=search-standalone",
#         "job_title": "Solution Manager (5G / IoT Solutions)",
#         "job_company": "China Mobile Hong Kong Company Limited",
#         "job_location": "Kwai Hing",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75950615?type=standout&ref=search-standalone",
#         "job_title": "Research Associate/Post-doctoral Fellow in NLP for Clinical Medicine",
#         "job_company": "Laboratory of Data Discovery for Health Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "3h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75950502?type=standout&ref=search-standalone",
#         "job_title": "AI Specialist/Senior AI Programmer (Ref.: 200171)",
#         "job_company": "Laboratory of Data Discovery for Health Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75950026?type=standard&ref=search-standalone",
#         "job_title": "Analyst Programmer / Senior Analyst Programmer",
#         "job_company": "Hong Leong Insurance (Asia) Limited",
#         "job_location": "North Point",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75949873?type=standard&ref=search-standalone",
#         "job_title": "Senior Analyst Programmer",
#         "job_company": "Hong Leong Insurance (Asia) Limited",
#         "job_location": "North Point",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75948969?type=standout&ref=search-standalone",
#         "job_title": "Assistant Officer, IT Application Development (Fresh Graduate Welcome)",
#         "job_company": "Airstar Bank Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75948730?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer (Ref# IT/ft/24-03)",
#         "job_company": "HKU SPACE Po Leung Kuk Stanley Ho Community College",
#         "job_location": "Causeway Bay",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75948732?type=standout&ref=search-standalone",
#         "job_title": "Backend Software Programmer",
#         "job_company": "ALTA Multimedia Ltd",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75948716?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer",
#         "job_company": "Hong Kong Baptist University",
#         "job_location": "Tsuen Wan",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75948567?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer",
#         "job_company": "Hong Kong Baptist University",
#         "job_location": "Tsuen Wan",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75948417?type=standout&ref=search-standalone",
#         "job_title": "Senior Pricing Executive/Pricing Executive",
#         "job_company": "Air Sea Worldwide Logistics Ltd",
#         "job_location": "North Point",
#         "job_listing_date": "4h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947719?type=standout&ref=search-standalone",
#         "job_title": "Branch Teller (Well-known bank)",
#         "job_company": "Jobsdb - SmartHire",
#         "job_location": "Mong Kok",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947724?type=standard&ref=search-standalone",
#         "job_title": "Programmer / GIS Programmer",
#         "job_company": "Esri China (Hong Kong) Ltd",
#         "job_location": "Lai Chi Kok",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947603?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer (Computer Vision / Fresh Graduate is welcome)",
#         "job_company": "ASMPT Technology Hong Kong Limited",
#         "job_location": "Tsing Yi",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947538?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer - Integrated Textile Specialist Company",
#         "job_company": "Mclaren Consultancy Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947505?type=standard&ref=search-standalone",
#         "job_title": "數據庫開發工程師",
#         "job_company": "Elead Global Limited",
#         "job_location": "Kwun Tong District",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947405?type=standout&ref=search-standalone",
#         "job_title": "Senior System Specialist / System Specialist (FICO / COPA)",
#         "job_company": "ASMPT Technology Hong Kong Limited",
#         "job_location": "Tsing Yi",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947298?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer (C / C++ Preferred) (Fresh Graduate / IANG Holder Is Welcome)",
#         "job_company": "ASMPT Technology Hong Kong Limited",
#         "job_location": "Tsing Yi",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947066?type=standout&ref=search-standalone",
#         "job_title": "Networking Software (5G Network Integration)-Snr Engineer/Engineering Associate",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947016?type=standout&ref=search-standalone",
#         "job_title": "IT Officer in the Enterprise Solutions Office [Ref. D/388/03]",
#         "job_company": "City University of Hong Kong",
#         "job_location": "Kowloon City District",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75947001?type=standout&ref=search-standalone",
#         "job_title": "Software Developer / Programmer / Engineer",
#         "job_company": "Emerging Viral Diagnostics (HK) Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946969?type=standout&ref=search-standalone",
#         "job_title": "Smart Mobility - Backend - Senior Engineer / Engineer / Engineering Associate",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946921?type=standout&ref=search-standalone",
#         "job_title": "Smart Mobility - Simulation - Senior Engineer / Engineer / Engineering Associate",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946894?type=standout&ref=search-standalone",
#         "job_title": "Migration Specialist",
#         "job_company": "Ray White (Hong Kong) Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946584?type=standout&ref=search-standalone",
#         "job_title": "Technical Officer (Mobile App Developer)",
#         "job_company": "HKT",
#         "job_location": "Cheung Sha Wan",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946462?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer",
#         "job_company": "Texwinca Holdings Ltd",
#         "job_location": "Kwai Fong",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946308?type=standard&ref=search-standalone",
#         "job_title": "Analyst Programmer / Programmer (Ref: SSO/IT/P/JDB)",
#         "job_company": "Haven of Hope Christian Service",
#         "job_location": "Hong Kong",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75946076?type=standout&ref=search-standalone",
#         "job_title": "Programmer",
#         "job_company": "Belle Fashion Group",
#         "job_location": "Kwai Hing",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75513688?type=standout&ref=search-standalone",
#         "job_title": "IT Business Analyst (Application support)",
#         "job_company": "Dah Chong Hong Motors International Holdings Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "5h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75945716?type=standout&ref=search-standalone",
#         "job_title": "Smart Mobility - Frontend - Senior Engineer / Engineer / Engineering Associate",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "6h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75945658?type=standout&ref=search-standalone",
#         "job_title": "Smart Mobility - AI - Senior Engineer / Engineer / Engineering Associate",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "6h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75945415?type=standout&ref=search-standalone",
#         "job_title": "Snr Engineer / Engineer / Engineering Associate (PI), 5G Core Development",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "6h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75945204?type=standout&ref=search-standalone",
#         "job_title": "Smart Mobility - Snr Engineer (PI) / Engineer (PI) / Engineering Associate (PI)",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "6h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75944889?type=standout&ref=search-standalone",
#         "job_title": "Snr Engineer / Engineer / Engineering Associate (PI), 5G Core Development",
#         "job_company": "Hong Kong Applied Science and Technology Research Institute Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "6h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75940045?type=standard&ref=search-standalone",
#         "job_title": "Survey Officer Trainee (Planning)",
#         "job_company": "Civil Service Bureau",
#         "job_location": "Hong Kong",
#         "job_listing_date": "15h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75938203?type=standard&ref=search-standalone",
#         "job_title": "Survey Officer (Planning)",
#         "job_company": "Civil Service Bureau",
#         "job_location": "Hong Kong",
#         "job_listing_date": "15h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75937864?type=standout&ref=search-standalone",
#         "job_title": "HIL Test Engineer",
#         "job_company": "DXC Technology Enterprise Services (Hong Kong) Limited",
#         "job_location": "Tai Koo",
#         "job_listing_date": "16h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75936498?type=standout&ref=search-standalone",
#         "job_title": "Computershare Governance Services - Register Your Interest",
#         "job_company": "Computershare Hong Kong Investor Services Limited",
#         "job_location": "Wan Chai District",
#         "job_listing_date": "16h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75939131?type=standard&ref=search-standalone",
#         "job_title": "程序員/ 程序分析員(In-house)",
#         "job_company": "東方人力資源有限公司",
#         "job_location": "Tai Po Industrial Estate",
#         "job_listing_date": "20h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75933008?type=standout&ref=search-standalone",
#         "job_title": "Junior Programmer (double pay+bonus)",
#         "job_company": "Same Page Recruitment Co",
#         "job_location": "Tuen Mun District",
#         "job_listing_date": "20h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932894?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer/Senior Analyst Programmer (Statutory Body)",
#         "job_company": "PERSOLKELLY Hong Kong Limited",
#         "job_location": "Wan Chai District",
#         "job_listing_date": "21h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932874?type=standout&ref=search-standalone",
#         "job_title": "Senior /Analyst Programmer (C# /.Net) (Ref:026)",
#         "job_company": "Triangle Recruitment",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "21h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932537?type=standout&ref=search-standalone",
#         "job_title": "Software Quality Assurance Engineer (Manual)",
#         "job_company": "KS Labs Hong Kong Limited",
#         "job_location": "Central",
#         "job_listing_date": "21h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932515?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer (Java)",
#         "job_company": "Nexify Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "21h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74638921?type=standout&ref=search-standalone",
#         "job_title": "System Analysis (Institutional Business)",
#         "job_company": "Guotai Junan International Holdings Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "21h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932392?type=standout&ref=search-standalone",
#         "job_title": "Mobile App Developer",
#         "job_company": "Nexify Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "21h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/72971141?type=standard&ref=search-standalone",
#         "job_title": "Officer - System Development (ITD)",
#         "job_company": "Christian Action",
#         "job_location": "Wong Tai Sin District",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932189?type=standout&ref=search-standalone",
#         "job_title": "Technical Executive (Green Building) – Technical Services",
#         "job_company": "BEAM Society Limited",
#         "job_location": "Kowloon Tong",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932197?type=standout&ref=search-standalone",
#         "job_title": "(Fresh Grad Welcome) Java/ Web /Mobile Application Developer (20K-55K)",
#         "job_company": "Manpower Services (Hong Kong) Limited",
#         "job_location": "Wan Chai District",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932147?type=standout&ref=search-standalone",
#         "job_title": "(Senior) System Analyst (React.js/React Native) - Up to 60K",
#         "job_company": "Manpower Services (Hong Kong) Limited",
#         "job_location": "Tai Kok Tsui",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75932123?type=standout&ref=search-standalone",
#         "job_title": "Developer /Programmer/ Analyst Programmer (Java/ Mobile App/ Web) (20K-55K)",
#         "job_company": "Manpower Services (Hong Kong) Limited",
#         "job_location": "Kowloon",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75931794?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer",
#         "job_company": "Solos Technology Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75931396?type=standard&ref=search-standalone",
#         "job_title": "Assistant Engineer / Engineer (Software)",
#         "job_company": "Centre For Garment Production Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/73641806?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer/ Java Developer (Frontend / Backend)",
#         "job_company": "Hutchison Telecommunications (Hong Kong) Limited",
#         "job_location": "Tsing Yi",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/73086502?type=standout&ref=search-standalone",
#         "job_title": "Senior System Administrator/Specialist",
#         "job_company": "Hutchison Telecommunications (Hong Kong) Limited",
#         "job_location": "Tsing Yi",
#         "job_listing_date": "22h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75930265?type=standout&ref=search-standalone",
#         "job_title": "Line Analyst",
#         "job_company": "ZIM Integrated Shipping Services Ltd",
#         "job_location": "Ngau Tau Kok",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929848?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer (Fresh graduate welcome) (Ref.: 200160)",
#         "job_company": "Laboratory of Data Discovery for Health Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929754?type=standout&ref=search-standalone",
#         "job_title": "AIGC Engineer - Digital Human Technology Expert",
#         "job_company": "Brightoil Petroleum (S'pore) Pte. Ltd.",
#         "job_location": "Sheung Wan",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929699?type=standout&ref=search-standalone",
#         "job_title": "AI Programmer/Specialist (Ref.: 200127)",
#         "job_company": "Laboratory of Data Discovery for Health Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929679?type=standout&ref=search-standalone",
#         "job_title": "Web3 Engineer",
#         "job_company": "VX Real Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929676?type=standard&ref=search-standalone",
#         "job_title": "Assistant IT Engineer / IT Engineer (Support)",
#         "job_company": "Yuanta Securities (Hong Kong) Company Limited",
#         "job_location": "Admiralty",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929564?type=standout&ref=search-standalone",
#         "job_title": "Frontend Engineer",
#         "job_company": "VX Real Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929601?type=standard&ref=search-standalone",
#         "job_title": "Programmer (Backend / AI)",
#         "job_company": "Centre for Perceptual and Interactive Intelligence (CPII) Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929531?type=standout&ref=search-standalone",
#         "job_title": "AI Engineer",
#         "job_company": "VX Real Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929532?type=standard&ref=search-standalone",
#         "job_title": "Programmer (Frontend)",
#         "job_company": "Centre for Perceptual and Interactive Intelligence (CPII) Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74462578?type=standard&ref=search-standalone",
#         "job_title": "Technical Support Engineer",
#         "job_company": "Fly Higher Information Technology Limited",
#         "job_location": "Yau Tsim Mong District",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929482?type=standout&ref=search-standalone",
#         "job_title": "Programmer / Analyst Programmer at Win Growth Limited",
#         "job_company": "Jobsdb - SmartHire",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75939298?type=standard&ref=search-standalone",
#         "job_title": "Assistant Manager, Data Solution",
#         "job_company": "Prudential Hong Kong Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929272?type=standard&ref=search-standalone",
#         "job_title": "Frontend Developer (Health-related Project)",
#         "job_company": "Centre for Perceptual and Interactive Intelligence (CPII) Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75929012?type=standout&ref=search-standalone",
#         "job_title": "Network Engineer (fixed night shift) (up to HKD 25K) (open to freshgrad)",
#         "job_company": "TalentQuest HR Limited",
#         "job_location": "Central",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74394737?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer / Programmer (FinTech/Banking - Mobile / Web Application)",
#         "job_company": "Infinite Financial Solutions Limited",
#         "job_location": "Wan Chai",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74424852?type=standout&ref=search-standalone",
#         "job_title": "Senior Analyst Programmer/ System Analyst (FinTech/Banking- Web/Mobile App)",
#         "job_company": "Infinite Financial Solutions Limited",
#         "job_location": "Wan Chai",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75824218?type=standard&ref=search-standalone",
#         "job_title": "Backend Developer (Health-related Project)",
#         "job_company": "Centre for Perceptual and Interactive Intelligence (CPII) Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "23h ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75705204?type=standard&ref=search-standalone",
#         "job_title": "Senior / Systems Analyst",
#         "job_company": "Bangkok Bank Public Co Ltd",
#         "job_location": "Central",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75704841?type=standard&ref=search-standalone",
#         "job_title": "Analyst Programmer / Senior Programmer",
#         "job_company": "Bangkok Bank Public Co Ltd",
#         "job_location": "Central",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75927890?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer - Perm",
#         "job_company": "DXC Technology Enterprise Services (Hong Kong) Limited",
#         "job_location": "Wan Chai District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75927836?type=standout&ref=search-standalone",
#         "job_title": "Programmer / Analyst Programmer (5 days work)",
#         "job_company": "Innovative Associate Technology Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75927842?type=standout&ref=search-standalone",
#         "job_title": "Java Software Engineer, Investment Bank, Renewable Contract",
#         "job_company": "Morgan Mckinley Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75925603?type=standout&ref=search-standalone",
#         "job_title": "Senior Analyst Programmer, .Net Core, Insurance",
#         "job_company": "Robert Walters (HK) Ltd",
#         "job_location": "Central and Western District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75924354?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer",
#         "job_company": "UNRE AI Limited",
#         "job_location": "Science Park",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75923675?type=standout&ref=search-standalone",
#         "job_title": "Senior Programmer / Programmer",
#         "job_company": "Data World Solutions Limited",
#         "job_location": "Kwai Hing",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75923601?type=standout&ref=search-standalone",
#         "job_title": "Unity Game Developer",
#         "job_company": "Foonie Magus Pte. Ltd.",
#         "job_location": "Causeway Bay",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75921848?type=standout&ref=search-standalone",
#         "job_title": "AI Research Engineer",
#         "job_company": "Hong Kong Biotechnology Organization",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75921823?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer / Senior Analyst Programmer (.NET, MSSQL) (5-Day Work)",
#         "job_company": "Global Logistics System (HK) Co Ltd",
#         "job_location": "Airport Area",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75921707?type=standout&ref=search-standalone",
#         "job_title": "Senior/Analyst Programmer (Ref:013)",
#         "job_company": "Triangle Recruitment",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75921258?type=standout&ref=search-standalone",
#         "job_title": "Data Migration Specialist",
#         "job_company": "The Career Works Limited",
#         "job_location": "Wong Chuk Hang",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75920889?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer (AI, Python)",
#         "job_company": "Computer Recruitment Consultants Ltd",
#         "job_location": "Hong Kong",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75920690?type=standout&ref=search-standalone",
#         "job_title": "Senior Analyst Programmer (Java)/ Analyst Programmer (Fresh grad welcome)",
#         "job_company": "Peplink International Limited",
#         "job_location": "Lai Chi Kok",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75919693?type=standout&ref=search-standalone",
#         "job_title": "Full Stack/Fullstack Programmer/Developer - Ecommerce Platform",
#         "job_company": "Seal Technology (Hong Kong) Limited",
#         "job_location": "Sha Tin",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75919198?type=standout&ref=search-standalone",
#         "job_title": "Software QA Engineer (Manual)",
#         "job_company": "Pyro Entertainment Limited",
#         "job_location": "Wan Chai",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75917630?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer (.NET), Public Transport, 1 year contract",
#         "job_company": "ConnectedGroup Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75916760?type=standout&ref=search-standalone",
#         "job_title": "DevOps Engineer",
#         "job_company": "Oasis Headquarters Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75916765?type=standard&ref=search-standalone",
#         "job_title": "Solutions Consultant / Support",
#         "job_company": "Kyocera Document Solutions Hong Kong Limited",
#         "job_location": "Tsuen Wan District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75916778?type=standard&ref=search-standalone",
#         "job_title": "Part-time Project Technical Assistant (two posts)",
#         "job_company": "The Hong Kong Polytechnic University",
#         "job_location": "Hung Hom",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75203167?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer",
#         "job_company": "EC Healthcare",
#         "job_location": "Quarry Bay",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75915416?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer - With Client Server Experiences (VCO209/J45)",
#         "job_company": "VTECH Corporate Services Ltd",
#         "job_location": "Tai Po District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75915221?type=standout&ref=search-standalone",
#         "job_title": "Digital Developer",
#         "job_company": "Collinson International (Hong Kong) Limited",
#         "job_location": "Quarry Bay",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75915148?type=standout&ref=search-standalone",
#         "job_title": "System Analyst/ Developer (C# and SQL and M365)",
#         "job_company": "Value Partners Ltd",
#         "job_location": "Central and Western District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75914365?type=standout&ref=search-standalone",
#         "job_title": "Product Developer at Levi Strauss (Hong Kong) Limited",
#         "job_company": "Jobsdb - SmartHire",
#         "job_location": "Kwun Tong District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/72907379?type=standout&ref=search-standalone",
#         "job_title": "Junior System Engineer (Secondment Contract)",
#         "job_company": "China Taiping Life Insurance (Hong Kong) Company Limited",
#         "job_location": "North Point",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75914141?type=standout&ref=search-standalone",
#         "job_title": "System Analyst/ Programmer (Java) /System engineer(Window) /Operator",
#         "job_company": "Mtel Career Consulting",
#         "job_location": "Kowloon",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75911383?type=standout&ref=search-standalone",
#         "job_title": "3D Design & Implementation Specialist (Thai proficiency required)",
#         "job_company": "CLO Virtual Fashion HK Limited",
#         "job_location": "Wan Chai District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75911138?type=standout&ref=search-standalone",
#         "job_title": "3D Design & Implementation Specialist (3D Fashion Design)",
#         "job_company": "CLO Virtual Fashion HK Limited",
#         "job_location": "Wan Chai District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75907576?type=standout&ref=search-standalone",
#         "job_title": "超市店務員 (旺角/長沙灣/黃大仙/葵芳) 14k - 18k+",
#         "job_company": "Yau Shing Food Wholesale Limited",
#         "job_location": "Sham Shui Po",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75936755?type=standard&ref=search-standalone",
#         "job_title": "Software Engineer",
#         "job_company": "UNRE AI Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75896146?type=standout&ref=search-standalone",
#         "job_title": "IT Lead Engineer - Derivatives  Platform",
#         "job_company": "KOS International Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "1d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75854564?type=standout&ref=search-standalone",
#         "job_title": "Linux Sr. Systems Engr.–Infrastructure Critical Svcs.–IT–Associate (R000782)",
#         "job_company": "Hong Kong Exchanges & Clearing Ltd",
#         "job_location": "Hong Kong",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75801240?type=standout&ref=search-standalone",
#         "job_title": "MSP Engineer",
#         "job_company": "SDAP",
#         "job_location": "Sai Ying Pun",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75841883?type=standard&ref=search-standalone",
#         "job_title": "Associate – Data Analytics and Reporting - CMD - FCS - Hong Kong",
#         "job_company": "PwC",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75843975?type=standard&ref=search-standalone",
#         "job_title": "手機系統分析員 (Mobile App Developer)",
#         "job_company": "東方人力資源有限公司",
#         "job_location": "Tai Po",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75843747?type=standard&ref=search-standalone",
#         "job_title": "遊戲開發工程師(遊戲編程員)",
#         "job_company": "心靈藝想心理健康有限公司",
#         "job_location": "New Territories",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75843108?type=standard&ref=search-standalone",
#         "job_title": "軟件工程師",
#         "job_company": "AMBER ROAD (HONG KONG) LIMITED",
#         "job_location": "Ngau Tau Kok",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75843937?type=standard&ref=search-standalone",
#         "job_title": "資深軟件工程師",
#         "job_company": "中國雲技術有限公司",
#         "job_location": "Kwai Chung",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839684?type=standout&ref=search-standalone",
#         "job_title": "Flutter Developer",
#         "job_company": "Keysoc Limited",
#         "job_location": "Cheung Sha Wan",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839496?type=standout&ref=search-standalone",
#         "job_title": "Devops Engineer",
#         "job_company": "Aurex Group Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839375?type=standout&ref=search-standalone",
#         "job_title": "Business System Analyst (Confidential)",
#         "job_company": "Aurex Group Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839364?type=standout&ref=search-standalone",
#         "job_title": "Analyst Developer (C# / .NET)",
#         "job_company": "Rise Associates Asia Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839313?type=standout&ref=search-standalone",
#         "job_title": "Senior/ Onsite Technician, Audiovisual system (perm.) - MNC (HKD 25-31K)",
#         "job_company": "TalentQuest HR Limited",
#         "job_location": "Central",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839172?type=standout&ref=search-standalone",
#         "job_title": "Backend Developer (Ruby on Rails / Node.js)",
#         "job_company": "Keysoc Limited",
#         "job_location": "Lai Chi Kok",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839153?type=standard&ref=search-standalone",
#         "job_title": "QA Tester(遊戲測試員) - Fresh graduates are welcome",
#         "job_company": "Qookia Limited",
#         "job_location": "Kwai Fong",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75839065?type=standout&ref=search-standalone",
#         "job_title": "Quality Assurance Engineer - Mobile Apps & Websites",
#         "job_company": "Keysoc Limited",
#         "job_location": "Cheung Sha Wan",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75838957?type=standout&ref=search-standalone",
#         "job_title": "Senior System Analyst - Insurtech",
#         "job_company": "Aurex Group Limited",
#         "job_location": "Central and Western District",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75836138?type=standout&ref=search-standalone",
#         "job_title": "Consumer Interactive Summer Internship 2024  (Undergraduate students only)",
#         "job_company": "TransUnion Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75836023?type=standout&ref=search-standalone",
#         "job_title": "Product Management Summer Internship 2024  (Undergraduate students Only)",
#         "job_company": "TransUnion Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75835921?type=standout&ref=search-standalone",
#         "job_title": "IT Operation engineer (Application Support)",
#         "job_company": "AT Global Services Limited",
#         "job_location": "Wan Chai",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75835491?type=standout&ref=search-standalone",
#         "job_title": "Programmer (Fresh Graduates Are Welcome ! )",
#         "job_company": "HKT Enterprise Solutions",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75834956?type=standout&ref=search-standalone",
#         "job_title": "Senior Fullstack Developer - Flexible Working Environment",
#         "job_company": "TEKsystems",
#         "job_location": "Central",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75841108?type=standard&ref=search-standalone",
#         "job_title": "資訊科技實習生",
#         "job_company": "Company Confidential",
#         "job_location": "Hong Kong",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75834556?type=standout&ref=search-standalone",
#         "job_title": "Data Solutions Architect - 40k + bonus",
#         "job_company": "Robert Walters (HK) Ltd",
#         "job_location": "Central and Western District",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75834452?type=standout&ref=search-standalone",
#         "job_title": "Senior / Frontend Developer l Marketing l HKD $40k",
#         "job_company": "Ambitious People Hong Kong Limited",
#         "job_location": "Quarry Bay",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/73325497?type=standout&ref=search-standalone",
#         "job_title": "(Senior) Tester (Double pay + Bonus)",
#         "job_company": "On Way Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75834345?type=standout&ref=search-standalone",
#         "job_title": "Frontend Developer | Content Platform | $25-40k",
#         "job_company": "Ambitious People Hong Kong Limited",
#         "job_location": "Hong Kong Island",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75834307?type=standout&ref=search-standalone",
#         "job_title": "Product Manager, IT Department 產品經理崗 (機構業務 / 互聯網業務)",
#         "job_company": "China Merchants Securities International Company Limited",
#         "job_location": "Kwun Tong",
#         "job_listing_date": "2d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/74314849?type=standout&ref=search-standalone",
#         "job_title": "Frontend Engineer /Developer (Double pay, Bonus, 14 days AL)",
#         "job_company": "On Way Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75833880?type=standout&ref=search-standalone",
#         "job_title": "Frontend Developer (Angular)",
#         "job_company": "RV Automation Technology Company Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75833683?type=standard&ref=search-standalone",
#         "job_title": "Programmer / Analyst Programmer – C# / ASP / VB(EA)",
#         "job_company": "SC Fulfil Ltd",
#         "job_location": "Mong Kok",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75833645?type=standout&ref=search-standalone",
#         "job_title": "IT Analyst (Application Support) (35K)",
#         "job_company": "Manpower Services (Hong Kong) Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75833274?type=standout&ref=search-standalone",
#         "job_title": "AI Engineer",
#         "job_company": "Green Tomato Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75833221?type=standout&ref=search-standalone",
#         "job_title": "Project Engineer - System / Software Development (Work-life balance)",
#         "job_company": "Top Level Corporation Limited",
#         "job_location": "Kowloon Bay",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75831229?type=standout&ref=search-standalone",
#         "job_title": "Software Engineer",
#         "job_company": "FundPark Limited",
#         "job_location": "Kwun Tong District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75830887?type=standout&ref=search-standalone",
#         "job_title": "Frontend Developer",
#         "job_company": "瓦拉網絡有限公司",
#         "job_location": "Kwun Tong District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75830614?type=standout&ref=search-standalone",
#         "job_title": "Backend Developer",
#         "job_company": "瓦拉網絡有限公司",
#         "job_location": "Kwun Tong District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75830176?type=standout&ref=search-standalone",
#         "job_title": "Senior System Engineer / System Engineer",
#         "job_company": "Boardware Information System (HK) Limited",
#         "job_location": "Ngau Tau Kok",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75830370?type=standout&ref=search-standalone",
#         "job_title": "Web Developer / Programmer - (Front-End)",
#         "job_company": "Perfect Health Clinic Limited",
#         "job_location": "Mong Kok",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75830224?type=standout&ref=search-standalone",
#         "job_title": "Programmer",
#         "job_company": "NEC Hong Kong Limited",
#         "job_location": "Hong Kong",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75830190?type=standout&ref=search-standalone",
#         "job_title": "Analyst Programmer / Web Developer - (Front- End - React.JS)",
#         "job_company": "Next App Limited",
#         "job_location": "Mong Kok",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75828929?type=standout&ref=search-standalone",
#         "job_title": "Programmer (Client App)",
#         "job_company": "Mad Head App Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75790797?type=standout&ref=search-standalone",
#         "job_title": "Senior Programmer (Server)",
#         "job_company": "Mad Head App Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75828621?type=standout&ref=search-standalone",
#         "job_title": "Senior Programmer (Server)",
#         "job_company": "Mad Head App Limited",
#         "job_location": "Sha Tin District",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75827825?type=standout&ref=search-standalone",
#         "job_title": "Frontend / Backend / Full Stack Programmer ( Fresh Grad Welcome )",
#         "job_company": "Osmium Consulting Group Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75827139?type=standout&ref=search-standalone",
#         "job_title": "Software Quality Assurance Engineer - 20k up",
#         "job_company": "Mclaren Consultancy Limited",
#         "job_location": "Causeway Bay",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75826994?type=standout&ref=search-standalone",
#         "job_title": "Senior / Mobile Application Developer ( Swift / Kotlin )",
#         "job_company": "Osmium Consulting Group Limited",
#         "job_location": "Tsim Sha Tsui",
#         "job_listing_date": "3d ago"
#     },
#     {
#         "job_Link": "https://hk.jobsdb.com/job/75826962?type=standout&ref=search-standalone",
#         "job_title": "Building Services Inspector",
#         "job_company": "Alliance Contracting Co Ltd",
#         "job_location": "Hong Kong",
#         "job_listing_date": "3d ago"
#     }
# ]
