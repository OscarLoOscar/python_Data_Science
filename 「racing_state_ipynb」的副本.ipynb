# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarLoOscar/python_Data_Science/blob/main/%E3%80%8Cracing_state_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 pandas openpyxl

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 定义目标 URL
url = "https://racing.hkjc.com/racing/chinese/racing-info/racing_course.aspx"

# 发送 HTTP 请求并获取响应
response = requests.get(url)
response.encoding = 'utf-8'  # 确保中文字符正确显示

# 使用 BeautifulSoup 解析 HTML 内容
soup = BeautifulSoup(response.text, 'html.parser')

# 找到所有包含赛道和场地状况的表格
tables = soup.find_all('table', {'class': 'body_text'})

# 创建一个空列表来存储数据
data = []

# 解析每个表格中的数据
for table in tables:
    rows = table.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [col.get_text(strip=True) for col in cols]
        if cols:  # 如果行不为空
            data.append(cols)

# 将数据转换为 DataFrame
df = pd.DataFrame(data)

# %%
display(df)
# Out:
#        0       1     2      3
# 0     沙田    None  None   None
# 1     跑道    直路長度    闊度   None
# 2     A:    A 賽道  430米  30.5米
# 3   A+2:  A+2 賽道  430米  28.5米
# 4   A+3:  A+3 賽道  430米  27.5米
# ..   ...     ...   ...    ...
# 89     6      直路  400m   None
# 90     7      直路  200m   None
# 91     8     終點柱    0m   None
# 92                       None
# 93                       None
#
# [94 rows x 4 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

# 保存为 Excel 文件到 Google Drive
output_file = '/content/drive/My Drive/racing_course_info.xlsx'
df.to_excel(output_file, index=False)

print(f"数据已保存至 {output_file}")
# Out:
# 数据已保存至 /content/drive/My Drive/racing_course_info.xlsx

# %%
display(df)
# Out:
#                                                      0              1            2      3
# 0                                                   沙田           None         None   None
# 1                                                   跑道           直路長度           闊度   None
# 2                                                   A:           A 賽道         430米  30.5米
# 3                                                 A+2:         A+2 賽道         430米  28.5米
# 4                                                 A+3:         A+3 賽道         430米  27.5米
# 5                                                   B:           B 賽道         430米    26米
# 6                                                 B+2:         B+2 賽道         430米    24米
# 7                                                   C:           C 賽道         430米  21.3米
# 8                                                 C+3:         C+3 賽道         430米  18.3米
# ...
